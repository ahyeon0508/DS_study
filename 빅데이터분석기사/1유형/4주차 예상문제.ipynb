# %% [markdown]
# # 4주차 예상문제 1

# %% [markdown]
# 데이터 출처 :https://www.kaggle.com/teejmahal20/airline-passenger-satisfaction?select=train.csv (참고, 데이터 수정)
#
# 데이터 설명 : 비행탑승 경험 만족도 (satisfaction 컬럼 : 'neutral or dissatisfied' or satisfied )   (83123, 24) shape
#
# Data url :https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/train.csv
#
# 출처 : 4주차 예상문제 1 (이기적 스터디 카페 / 컴활,정보처리,빅분기) | 작성자 빅분기 실기조교

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/train.csv")

# %%
df
# Out:
#            id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0       55882    Male  Loyal Customer   42  Business travel  Business
# 1       31906  Female  Loyal Customer   31  Business travel  Business
# 2       85481    Male  Loyal Customer   51  Personal Travel       Eco
# 3      102134    Male  Loyal Customer   44  Business travel  Business
# 4       31580    Male  Loyal Customer   33  Business travel  Business
# ...       ...     ...             ...  ...              ...       ...
# 83118    9745    Male  Loyal Customer   39  Business travel  Business
# 83119    5190    Male  Loyal Customer   49  Business travel  Business
# 83120   41381  Female  Loyal Customer   62  Business travel  Business
# 83121   79829  Female  Loyal Customer   53  Business travel  Business
# 83122   84734  Female  Loyal Customer   51  Business travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 0                  473                      1
# 1                 3271                      4
# 2                  214                      5
# 3                 3097                      1
# 4                 3286                      1
# ...                ...                    ...
# 83118             3706                      1
# 83119              295                      0
# 83120             1914                      3
# 83121             3681                      2
# 83122             2943                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                      1                       3  ...
# 1                                      4                       4  ...
# 2                                      0                       5  ...
# 3                                      1                       3  ...
# 4                                      1                       1  ...
# ...                                  ...                     ...  ...
# 83118                                  1                       1  ...
# 83119                                  0                       0  ...
# 83120                                  5                       5  ...
# 83121                                  2                       2  ...
# 83122                                  2                       2  ...
#
#        Inflight entertainment  On-board service  Leg room service  \
# 0                           5                 5                 5
# 1                           3                 3                 5
# 2                           3                 4                 4
# 3                           4                 4                 4
# 4                           4                 2                 5
# ...                       ...               ...               ...
# 83118                       4                 4                 4
# 83119                       1                 1                 1
# 83120                       3                 3                 3
# 83121                       4                 4                 4
# 83122                       4                 4                 4
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                     5                3                 5            3
# 1                     5                3                 4            3
# 2                     4                4                 4            3
# 3                     4                3                 4            5
# 4                     2                5                 1            4
# ...                 ...              ...               ...          ...
# 83118                 4                2                 4            4
# 83119                 1                4                 1            4
# 83120                 3                3                 3            3
# 83121                 4                3                 4            3
# 83122                 4                5                 4            3
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               3                       0.0
# 1                               1                       5.0
# 2                               2                       0.0
# 3                               0                       0.0
# 4                               0                       0.0
# ...                           ...                       ...
# 83118                           1                       0.0
# 83119                           0                       0.0
# 83120                          64                      48.0
# 83121                          45                      21.0
# 83122                           0                       0.0
#
#                   satisfaction
# 0                    satisfied
# 1                    satisfied
# 2                    satisfied
# 3                    satisfied
# 4                    satisfied
# ...                        ...
# 83118                satisfied
# 83119                satisfied
# 83120  neutral or dissatisfied
# 83121                satisfied
# 83122                satisfied
#
# [83123 rows x 24 columns]

# %% [markdown]
# ## Q1. Arrival Delay in Minutes 컬럼이 결측치인 데이터들 중 'neutral or dissatisfied' 보다 'satisfied'의 수가 더 높은 Class는 어디인가?

# %%
temp_df = df[df['Arrival Delay in Minutes'].isnull()]

# %%
temp_df.groupby(['satisfaction', 'Class'], as_index=False).size().pivot(index='Class', columns='satisfaction')
# Out:
#                                 size
# satisfaction neutral or dissatisfied satisfied
# Class
# Business                          36        76
# Eco                              100        25
# Eco Plus                          15         4

# %% [markdown]
# => Business

# %% [markdown]
# -------

# %% [markdown]
# # 4주차 예상문제 2

# %% [markdown]
# 데이터 출처 :https://www.kaggle.com/adityakadiwal/water-potability
#
# (참고, 데이터 수정)
#
# 데이터 설명 : 수질 음용성 여부 (Potablillity 컬럼 : 0 ,1 )
#
# Data url :https://raw.githubusercontent.com/Datamanim/datarepo/main/waters/train.csv
#
# 출처 : 4주차 예상문제 2 (이기적 스터디 카페 / 컴활,정보처리,빅분기) | 작성자 빅분기 실기조교

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/waters/train.csv")

# %%
temp_df = df[~df['ph'].isnull()]

# %%
temp_df['ph'].quantile(0.25)
# Out:
# 6.069363893970801

# %%
temp_df[temp_df['ph'] <= temp_df['ph'].quantile(0.25)]['ph'].mean()
# Out:
# 5.057093462441732
